# %%
import pandas as pd
import numpy as np

# %%
# Series() is used for 1-d dataset
# Series is represented as indexes and values
pd.Series([10,20,30,40,50,60,70])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
# Collection of Series
data_series = {'Column1':pd.Series([10,20,30,40,50,60,70],index = ['a','b','c','d','e','f','g']),
 'Column2':pd.Series([100,200,300,400,500,600,700],index = ['a','b','c','d','e','f','g'])}

# %%
print(data_series)
# Out:
# {'Column1': a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# dtype: int64, 'Column2': a    100
# b    200
# c    300
# d    400
# e    500
# f    600
# g    700
# dtype: int64}

# %%
# Display dataframe
pd.DataFrame(data_series)
# Out:
#    Column1  Column2
# 0       10      100
# 1       20      200
# 2       30      300
# 3       40      400
# 4       50      500
# 5       60      600
# 6       70      700

# %%
# Create a DataFrame using dataset
autoprice_DF = pd.read_csv('Automobile_price_data__Raw_.csv')
autoprice_DF.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19    3.40              10.0        102      5500       24
# 4         mpfi  3.19    3.40               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
display(autoprice_DF)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19    3.40              10.0        102
# 4            136         mpfi  3.19    3.40               8.0        115
# ..           ...          ...   ...     ...               ...        ...
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01    3.40              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# ..        ...      ...         ...    ...
# 200      5400       23          28  16845
# 201      5300       19          25  19045
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 204      5400       19          25  22625
#
# [205 rows x 26 columns]

# %%
# isnull() -> return missing value as True and Flase for not null
autoprice_DF.isnull()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0         False         False            False       False  ...        False
# 1         False         False            False       False  ...        False
# 2         False         False            False       False  ...        False
# 3         False         False            False       False  ...        False
# 4         False         False            False       False  ...        False
# ..          ...           ...              ...         ...  ...          ...
# 200       False         False            False       False  ...        False
# 201       False         False            False       False  ...        False
# 202       False         False            False       False  ...        False
# 203       False         False            False       False  ...        False
# 204       False         False            False       False  ...        False
#
#      fuel-system   bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0          False  False   False              False       False     False
# 1          False  False   False              False       False     False
# 2          False  False   False              False       False     False
# 3          False  False   False              False       False     False
# 4          False  False   False              False       False     False
# ..           ...    ...     ...                ...         ...       ...
# 200        False  False   False              False       False     False
# 201        False  False   False              False       False     False
# 202        False  False   False              False       False     False
# 203        False  False   False              False       False     False
# 204        False  False   False              False       False     False
#
#      city-mpg  highway-mpg  price
# 0       False        False  False
# 1       False        False  False
# 2       False        False  False
# 3       False        False  False
# 4       False        False  False
# ..        ...          ...    ...
# 200     False        False  False
# 201     False        False  False
# 202     False        False  False
# 203     False        False  False
# 204     False        False  False
#
# [205 rows x 26 columns]

# %%
# notnull -> returns missing value as False and True for not null
autoprice_DF.notnull()
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0         True               True  True       True        True          True
# 1         True               True  True       True        True          True
# 2         True               True  True       True        True          True
# 3         True               True  True       True        True          True
# 4         True               True  True       True        True          True
# ..         ...                ...   ...        ...         ...           ...
# 200       True               True  True       True        True          True
# 201       True               True  True       True        True          True
# 202       True               True  True       True        True          True
# 203       True               True  True       True        True          True
# 204       True               True  True       True        True          True
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0          True          True             True        True  ...         True
# 1          True          True             True        True  ...         True
# 2          True          True             True        True  ...         True
# 3          True          True             True        True  ...         True
# 4          True          True             True        True  ...         True
# ..          ...           ...              ...         ...  ...          ...
# 200        True          True             True        True  ...         True
# 201        True          True             True        True  ...         True
# 202        True          True             True        True  ...         True
# 203        True          True             True        True  ...         True
# 204        True          True             True        True  ...         True
#
#      fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0           True  True    True               True        True      True
# 1           True  True    True               True        True      True
# 2           True  True    True               True        True      True
# 3           True  True    True               True        True      True
# 4           True  True    True               True        True      True
# ..           ...   ...     ...                ...         ...       ...
# 200         True  True    True               True        True      True
# 201         True  True    True               True        True      True
# 202         True  True    True               True        True      True
# 203         True  True    True               True        True      True
# 204         True  True    True               True        True      True
#
#      city-mpg  highway-mpg  price
# 0        True         True   True
# 1        True         True   True
# 2        True         True   True
# 3        True         True   True
# 4        True         True   True
# ..        ...          ...    ...
# 200      True         True   True
# 201      True         True   True
# 202      True         True   True
# 203      True         True   True
# 204      True         True   True
#
# [205 rows x 26 columns]

# %%
autoprice_DF.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# sum of missing rows present in each column
autoprice_DF.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
autoprice_DF.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# min    1488.000000    61.000000           7.000000   13.000000    16.000000
# 25%    2145.000000    97.000000           8.600000   19.000000    25.000000
# 50%    2414.000000   120.000000           9.000000   24.000000    30.000000
# 75%    2935.000000   141.000000           9.400000   30.000000    34.000000
# max    4066.000000   326.000000          23.000000   49.000000    54.000000

# %%
# replace '?' by np.nan
autoprice_DF.replace('?',np.nan,inplace = True)

# %%
# sum of missing rows present in each column
autoprice_DF.isna().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#select 'price' column
autoprice_DF['price']
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: object

# %%
autoprice_DF[autoprice_DF['price'].isnull() == True]
# Out:
#      symboling normalized-losses     make fuel-type aspiration num-of-doors  \
# 9            0               NaN     audi       gas      turbo          two
# 44           1               NaN    isuzu       gas        std          two
# 45           0               NaN    isuzu       gas        std         four
# 129          1               NaN  porsche       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 9    hatchback          4wd           front        99.5  ...          131
# 44       sedan          fwd           front        94.5  ...           90
# 45       sedan          fwd           front        94.5  ...           90
# 129  hatchback          rwd           front        98.4  ...          203
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 9           mpfi  3.13    3.40               7.0        160      5500
# 44          2bbl  3.03    3.11               9.6         70      5400
# 45          2bbl  3.03    3.11               9.6         70      5400
# 129         mpfi  3.94    3.11              10.0        288      5750
#
#     city-mpg highway-mpg price
# 9         16          22   NaN
# 44        38          43   NaN
# 45        38          43   NaN
# 129       17          28   NaN
#
# [4 rows x 26 columns]

# %%
autoprice_DF.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2               NaN         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1               NaN         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0               NaN         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
# 5        sedan          fwd           front        99.8  ...          136
# 6        sedan          fwd           front       105.8  ...          136
# 7        wagon          fwd           front       105.8  ...          136
# 8        sedan          fwd           front       105.8  ...          131
# 9    hatchback          4wd           front        99.5  ...          131
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19    3.40              10.0        102      5500       24
# 4         mpfi  3.19    3.40               8.0        115      5500       18
# 5         mpfi  3.19    3.40               8.5        110      5500       19
# 6         mpfi  3.19    3.40               8.5        110      5500       19
# 7         mpfi  3.19    3.40               8.5        110      5500       19
# 8         mpfi  3.13    3.40               8.3        140      5500       17
# 9         mpfi  3.13    3.40               7.0        160      5500       16
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
# 5          25  15250
# 6          25  17710
# 7          25  18920
# 8          20  23875
# 9          22    NaN
#
# [10 rows x 26 columns]

# %%
autoprice_DF.loc[0:11,]
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           3               NaN  alfa-romero       gas        std
# 2           1               NaN  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2               NaN         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1               NaN         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0               NaN         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# 1           two  convertible          rwd           front        88.6  ...
# 2           two    hatchback          rwd           front        94.5  ...
# 3          four        sedan          fwd           front        99.8  ...
# 4          four        sedan          4wd           front        99.4  ...
# 5           two        sedan          fwd           front        99.8  ...
# 6          four        sedan          fwd           front       105.8  ...
# 7          four        wagon          fwd           front       105.8  ...
# 8          four        sedan          fwd           front       105.8  ...
# 9           two    hatchback          4wd           front        99.5  ...
# 10          two        sedan          rwd           front       101.2  ...
# 11         four        sedan          rwd           front       101.2  ...
#
#     engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0           130         mpfi  3.47    2.68               9.0        111
# 1           130         mpfi  3.47    2.68               9.0        111
# 2           152         mpfi  2.68    3.47               9.0        154
# 3           109         mpfi  3.19    3.40              10.0        102
# 4           136         mpfi  3.19    3.40               8.0        115
# 5           136         mpfi  3.19    3.40               8.5        110
# 6           136         mpfi  3.19    3.40               8.5        110
# 7           136         mpfi  3.19    3.40               8.5        110
# 8           131         mpfi  3.13    3.40               8.3        140
# 9           131         mpfi  3.13    3.40               7.0        160
# 10          108         mpfi  3.50    2.80               8.8        101
# 11          108         mpfi  3.50    2.80               8.8        101
#
#     peak-rpm city-mpg highway-mpg  price
# 0       5000       21          27  13495
# 1       5000       21          27  16500
# 2       5000       19          26  16500
# 3       5500       24          30  13950
# 4       5500       18          22  17450
# 5       5500       19          25  15250
# 6       5500       19          25  17710
# 7       5500       19          25  18920
# 8       5500       17          20  23875
# 9       5500       16          22    NaN
# 10      5800       23          29  16430
# 11      5800       23          29  16925
#
# [12 rows x 26 columns]

# %%
autoprice_DF.loc[:,['make','fuel-type']]
# Out:
#             make fuel-type
# 0    alfa-romero       gas
# 1    alfa-romero       gas
# 2    alfa-romero       gas
# 3           audi       gas
# 4           audi       gas
# ..           ...       ...
# 200        volvo       gas
# 201        volvo       gas
# 202        volvo       gas
# 203        volvo    diesel
# 204        volvo       gas
#
# [205 rows x 2 columns]

# %%
# start index = 'make',  stop_index = 'height'
autoprice_DF.loc[:,'make':'height']
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
#     engine-location  wheel-base  length  width  height
# 0             front        88.6   168.8   64.1    48.8
# 1             front        88.6   168.8   64.1    48.8
# 2             front        94.5   171.2   65.5    52.4
# 3             front        99.8   176.6   66.2    54.3
# 4             front        99.4   176.6   66.4    54.3
# ..              ...         ...     ...    ...     ...
# 200           front       109.1   188.8   68.9    55.5
# 201           front       109.1   188.8   68.8    55.5
# 202           front       109.1   188.8   68.9    55.5
# 203           front       109.1   188.8   68.9    55.5
# 204           front       109.1   188.8   68.9    55.5
#
# [205 rows x 11 columns]

# %%
# It slices data by row index and column index value
autoprice_DF.iloc[:,2:13]
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
#     engine-location  wheel-base  length  width  height
# 0             front        88.6   168.8   64.1    48.8
# 1             front        88.6   168.8   64.1    48.8
# 2             front        94.5   171.2   65.5    52.4
# 3             front        99.8   176.6   66.2    54.3
# 4             front        99.4   176.6   66.4    54.3
# ..              ...         ...     ...    ...     ...
# 200           front       109.1   188.8   68.9    55.5
# 201           front       109.1   188.8   68.8    55.5
# 202           front       109.1   188.8   68.9    55.5
# 203           front       109.1   188.8   68.9    55.5
# 204           front       109.1   188.8   68.9    55.5
#
# [205 rows x 11 columns]

# %% [markdown]
# ### Sort Values
#     * sort_values()

# %%
autoprice_DF.sort_values(by = ['make'],ascending=False).head(20)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 204         -1                95       volvo       gas      turbo
# 199         -1                74       volvo       gas      turbo
# 194         -2               103       volvo       gas        std
# 195         -1                74       volvo       gas        std
# 196         -2               103       volvo       gas        std
# 198         -2               103       volvo       gas      turbo
# 197         -1                74       volvo       gas        std
# 200         -1                95       volvo       gas        std
# 201         -1                95       volvo       gas      turbo
# 202         -1                95       volvo       gas        std
# 203         -1                95       volvo    diesel      turbo
# 188          2                94  volkswagen       gas        std
# 182          2               122  volkswagen    diesel        std
# 183          2               122  volkswagen       gas        std
# 184          2                94  volkswagen    diesel        std
# 185          2                94  volkswagen       gas        std
# 187          2                94  volkswagen    diesel      turbo
# 186          2                94  volkswagen       gas        std
# 189          3               NaN  volkswagen       gas        std
# 190          3               256  volkswagen       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 204         four        sedan          rwd           front       109.1  ...
# 199         four        wagon          rwd           front       104.3  ...
# 194         four        sedan          rwd           front       104.3  ...
# 195         four        wagon          rwd           front       104.3  ...
# 196         four        sedan          rwd           front       104.3  ...
# 198         four        sedan          rwd           front       104.3  ...
# 197         four        wagon          rwd           front       104.3  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 188         four        sedan          fwd           front        97.3  ...
# 182          two        sedan          fwd           front        97.3  ...
# 183          two        sedan          fwd           front        97.3  ...
# 184         four        sedan          fwd           front        97.3  ...
# 185         four        sedan          fwd           front        97.3  ...
# 187         four        sedan          fwd           front        97.3  ...
# 186         four        sedan          fwd           front        97.3  ...
# 189          two  convertible          fwd           front        94.5  ...
# 190          two    hatchback          fwd           front        94.5  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 204          141         mpfi  3.78    3.15               9.5        114
# 199          130         mpfi  3.62    3.15               7.5        162
# 194          141         mpfi  3.78    3.15               9.5        114
# 195          141         mpfi  3.78    3.15               9.5        114
# 196          141         mpfi  3.78    3.15               9.5        114
# 198          130         mpfi  3.62    3.15               7.5        162
# 197          141         mpfi  3.78    3.15               9.5        114
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01    3.40              23.0        106
# 188          109         mpfi  3.19    3.40              10.0        100
# 182           97          idi  3.01    3.40              23.0         52
# 183          109         mpfi  3.19    3.40               9.0         85
# 184           97          idi  3.01    3.40              23.0         52
# 185          109         mpfi  3.19    3.40               9.0         85
# 187           97          idi  3.01    3.40              23.0         68
# 186          109         mpfi  3.19    3.40               9.0         85
# 189          109         mpfi  3.19    3.40               8.5         90
# 190          109         mpfi  3.19    3.40               8.5         90
#
#      peak-rpm city-mpg highway-mpg  price
# 204      5400       19          25  22625
# 199      5100       17          22  18950
# 194      5400       23          28  12940
# 195      5400       23          28  13415
# 196      5400       24          28  15985
# 198      5100       17          22  18420
# 197      5400       24          28  16515
# 200      5400       23          28  16845
# 201      5300       19          25  19045
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 188      5500       26          32   9995
# 182      4800       37          46   7775
# 183      5250       27          34   7975
# 184      4800       37          46   7995
# 185      5250       27          34   8195
# 187      4500       37          42   9495
# 186      5250       27          34   8495
# 189      5500       24          29  11595
# 190      5500       24          29   9980
#
# [20 rows x 26 columns]

# %%
autoprice_DF['horsepower'] = autoprice_DF['horsepower'].astype('float16')

# %%
autoprice_DF['horsepower'].sort_values()
# Out:
# 18      48.0
# 182     52.0
# 184     52.0
# 90      55.0
# 158     56.0
#        ...
# 126    207.0
# 49     262.0
# 129    288.0
# 130      NaN
# 131      NaN
# Name: horsepower, Length: 205, dtype: float16

# %%
autoprice_DF.sort_values(by = 'horsepower',ascending=False).head(15)
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 129          1               NaN        porsche       gas        std
# 49           0               NaN         jaguar       gas        std
# 128          3               NaN        porsche       gas        std
# 127          3               NaN        porsche       gas        std
# 126          3               NaN        porsche       gas        std
# 105          3               194         nissan       gas      turbo
# 73           0               NaN  mercedes-benz       gas        std
# 74           1               NaN  mercedes-benz       gas        std
# 17           0               NaN            bmw       gas        std
# 16           0               NaN            bmw       gas        std
# 15           0               NaN            bmw       gas        std
# 48           0               NaN         jaguar       gas        std
# 47           0               145         jaguar       gas        std
# 75           1               NaN        mercury       gas      turbo
# 198         -2               103          volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 129          two    hatchback          rwd           front        98.4  ...
# 49           two        sedan          rwd           front       102.0  ...
# 128          two  convertible          rwd            rear        89.5  ...
# 127          two      hardtop          rwd            rear        89.5  ...
# 126          two      hardtop          rwd            rear        89.5  ...
# 105          two    hatchback          rwd           front        91.3  ...
# 73          four        sedan          rwd           front       120.9  ...
# 74           two      hardtop          rwd           front       112.0  ...
# 17          four        sedan          rwd           front       110.0  ...
# 16           two        sedan          rwd           front       103.5  ...
# 15          four        sedan          rwd           front       103.5  ...
# 48          four        sedan          rwd           front       113.0  ...
# 47          four        sedan          rwd           front       113.0  ...
# 75           two    hatchback          rwd           front       102.7  ...
# 198         four        sedan          rwd           front       104.3  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 129          203         mpfi  3.94    3.11              10.0      288.0
# 49           326         mpfi  3.54    2.76              11.5      262.0
# 128          194         mpfi  3.74    2.90               9.5      207.0
# 127          194         mpfi  3.74    2.90               9.5      207.0
# 126          194         mpfi  3.74    2.90               9.5      207.0
# 105          181         mpfi  3.43    3.27               7.8      200.0
# 73           308         mpfi  3.80    3.35               8.0      184.0
# 74           304         mpfi  3.80    3.35               8.0      184.0
# 17           209         mpfi  3.62    3.39               8.0      182.0
# 16           209         mpfi  3.62    3.39               8.0      182.0
# 15           209         mpfi  3.62    3.39               8.0      182.0
# 48           258         mpfi  3.63    4.17               8.1      176.0
# 47           258         mpfi  3.63    4.17               8.1      176.0
# 75           140         mpfi  3.78    3.12               8.0      175.0
# 198          130         mpfi  3.62    3.15               7.5      162.0
#
#      peak-rpm city-mpg highway-mpg  price
# 129      5750       17          28    NaN
# 49       5000       13          17  36000
# 128      5900       17          25  37028
# 127      5900       17          25  34028
# 126      5900       17          25  32528
# 105      5200       17          23  19699
# 73       4500       14          16  40960
# 74       4500       14          16  45400
# 17       5400       15          20  36880
# 16       5400       16          22  41315
# 15       5400       16          22  30760
# 48       4750       15          19  35550
# 47       4750       15          19  32250
# 75       5000       19          24  16503
# 198      5100       17          22  18420
#
# [15 rows x 26 columns]

# %%
autoprice_DF.sort_values(by = ['make','horsepower'],ascending=[False,True]).head(15)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 203         -1                95       volvo    diesel      turbo
# 194         -2               103       volvo       gas        std
# 195         -1                74       volvo       gas        std
# 196         -2               103       volvo       gas        std
# 197         -1                74       volvo       gas        std
# 200         -1                95       volvo       gas        std
# 204         -1                95       volvo       gas      turbo
# 202         -1                95       volvo       gas        std
# 201         -1                95       volvo       gas      turbo
# 198         -2               103       volvo       gas      turbo
# 199         -1                74       volvo       gas      turbo
# 182          2               122  volkswagen    diesel        std
# 184          2                94  volkswagen    diesel        std
# 187          2                94  volkswagen    diesel      turbo
# 192          0               NaN  volkswagen    diesel      turbo
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 203         four      sedan          rwd           front       109.1  ...
# 194         four      sedan          rwd           front       104.3  ...
# 195         four      wagon          rwd           front       104.3  ...
# 196         four      sedan          rwd           front       104.3  ...
# 197         four      wagon          rwd           front       104.3  ...
# 200         four      sedan          rwd           front       109.1  ...
# 204         four      sedan          rwd           front       109.1  ...
# 202         four      sedan          rwd           front       109.1  ...
# 201         four      sedan          rwd           front       109.1  ...
# 198         four      sedan          rwd           front       104.3  ...
# 199         four      wagon          rwd           front       104.3  ...
# 182          two      sedan          fwd           front        97.3  ...
# 184         four      sedan          fwd           front        97.3  ...
# 187         four      sedan          fwd           front        97.3  ...
# 192         four      sedan          fwd           front       100.4  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 203          145          idi  3.01    3.40              23.0      106.0
# 194          141         mpfi  3.78    3.15               9.5      114.0
# 195          141         mpfi  3.78    3.15               9.5      114.0
# 196          141         mpfi  3.78    3.15               9.5      114.0
# 197          141         mpfi  3.78    3.15               9.5      114.0
# 200          141         mpfi  3.78    3.15               9.5      114.0
# 204          141         mpfi  3.78    3.15               9.5      114.0
# 202          173         mpfi  3.58    2.87               8.8      134.0
# 201          141         mpfi  3.78    3.15               8.7      160.0
# 198          130         mpfi  3.62    3.15               7.5      162.0
# 199          130         mpfi  3.62    3.15               7.5      162.0
# 182           97          idi  3.01    3.40              23.0       52.0
# 184           97          idi  3.01    3.40              23.0       52.0
# 187           97          idi  3.01    3.40              23.0       68.0
# 192           97          idi  3.01    3.40              23.0       68.0
#
#      peak-rpm city-mpg highway-mpg  price
# 203      4800       26          27  22470
# 194      5400       23          28  12940
# 195      5400       23          28  13415
# 196      5400       24          28  15985
# 197      5400       24          28  16515
# 200      5400       23          28  16845
# 204      5400       19          25  22625
# 202      5500       18          23  21485
# 201      5300       19          25  19045
# 198      5100       17          22  18420
# 199      5100       17          22  18950
# 182      4800       37          46   7775
# 184      4800       37          46   7995
# 187      4500       37          42   9495
# 192      4500       33          38  13845
#
# [15 rows x 26 columns]

# %%
# show unique vales from a column
autoprice_DF['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
# show frequency of elements
autoprice_DF['make'].value_counts().sort_valueslues()
# Out:
# mercury           1
# renault           2
# alfa-romero       3
# chevrolet         3
# jaguar            3
# isuzu             4
# porsche           5
# saab              6
# plymouth          7
# audi              7
# bmw               8
# mercedes-benz     8
# dodge             9
# volvo            11
# peugot           11
# subaru           12
# volkswagen       12
# honda            13
# mitsubishi       13
# mazda            17
# nissan           18
# toyota           32
# Name: make, dtype: int64

# %%
type(autoprice_DF['make'].value_counts())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Drop function
#     * Dropping rows, dropping columns

# %%
# dropping is default by row
autoprice_DF.drop([0,1,2,3,4,5,6,7,8])
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 9            0               NaN   audi       gas      turbo          two
# 10           2               192    bmw       gas        std          two
# 11           0               192    bmw       gas        std         four
# 12           0               188    bmw       gas        std          two
# 13           0               188    bmw       gas        std         four
# ..         ...               ...    ...       ...        ...          ...
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 9    hatchback          4wd           front        99.5  ...          131
# 10       sedan          rwd           front       101.2  ...          108
# 11       sedan          rwd           front       101.2  ...          108
# 12       sedan          rwd           front       101.2  ...          164
# 13       sedan          rwd           front       101.2  ...          164
# ..         ...          ...             ...         ...  ...          ...
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 9           mpfi  3.13    3.40               7.0      160.0      5500
# 10          mpfi  3.50    2.80               8.8      101.0      5800
# 11          mpfi  3.50    2.80               8.8      101.0      5800
# 12          mpfi  3.31    3.19               9.0      121.0      4250
# 13          mpfi  3.31    3.19               9.0      121.0      4250
# ..           ...   ...     ...               ...        ...       ...
# 200         mpfi  3.78    3.15               9.5      114.0      5400
# 201         mpfi  3.78    3.15               8.7      160.0      5300
# 202         mpfi  3.58    2.87               8.8      134.0      5500
# 203          idi  3.01    3.40              23.0      106.0      4800
# 204         mpfi  3.78    3.15               9.5      114.0      5400
#
#     city-mpg highway-mpg  price
# 9         16          22    NaN
# 10        23          29  16430
# 11        23          29  16925
# 12        21          28  20970
# 13        21          28  21105
# ..       ...         ...    ...
# 200       23          28  16845
# 201       19          25  19045
# 202       18          23  21485
# 203       26          27  22470
# 204       19          25  22625
#
# [196 rows x 26 columns]

# %%
# drop columns
autoprice_DF.drop(['symboling','normalized-losses'],axis = 1,inplace = True)
autoprice_DF.head()
# Out:
#           make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0  alfa-romero       gas        std          two  convertible          rwd
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two    hatchback          rwd
# 3         audi       gas        std         four        sedan          fwd
# 4         audi       gas        std         four        sedan          4wd
#
#   engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 0           front        88.6   168.8   64.1  ...          130         mpfi
# 1           front        88.6   168.8   64.1  ...          130         mpfi
# 2           front        94.5   171.2   65.5  ...          152         mpfi
# 3           front        99.8   176.6   66.2  ...          109         mpfi
# 4           front        99.4   176.6   66.4  ...          136         mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0      111.0     5000       21           27
# 1  3.47   2.68                9.0      111.0     5000       21           27
# 2  2.68   3.47                9.0      154.0     5000       19           26
# 3  3.19   3.40               10.0      102.0     5500       24           30
# 4  3.19   3.40                8.0      115.0     5500       18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450
#
# [5 rows x 24 columns]

# %%
autoprice_DF.drop(['aspiration':'drive-wheels'],axis = 1,inplace = True)

# %%
autoprice_DF.drop([0,1,2,3,4,5,6,7,8],axis = 0).reset_index().drop('index',axis = 1)
# Out:
#       make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 0     audi       gas      turbo          two  hatchback          4wd
# 1      bmw       gas        std          two      sedan          rwd
# 2      bmw       gas        std         four      sedan          rwd
# 3      bmw       gas        std          two      sedan          rwd
# 4      bmw       gas        std         four      sedan          rwd
# ..     ...       ...        ...          ...        ...          ...
# 191  volvo       gas        std         four      sedan          rwd
# 192  volvo       gas      turbo         four      sedan          rwd
# 193  volvo       gas        std         four      sedan          rwd
# 194  volvo    diesel      turbo         four      sedan          rwd
# 195  volvo       gas      turbo         four      sedan          rwd
#
#     engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 0             front        99.5   178.2   67.9  ...          131         mpfi
# 1             front       101.2   176.8   64.8  ...          108         mpfi
# 2             front       101.2   176.8   64.8  ...          108         mpfi
# 3             front       101.2   176.8   64.8  ...          164         mpfi
# 4             front       101.2   176.8   64.8  ...          164         mpfi
# ..              ...         ...     ...    ...  ...          ...          ...
# 191           front       109.1   188.8   68.9  ...          141         mpfi
# 192           front       109.1   188.8   68.8  ...          141         mpfi
# 193           front       109.1   188.8   68.9  ...          173         mpfi
# 194           front       109.1   188.8   68.9  ...          145          idi
# 195           front       109.1   188.8   68.9  ...          141         mpfi
#
#      bore stroke  compression-ratio horsepower peak-rpm city-mpg  highway-mpg  \
# 0    3.13   3.40                7.0      160.0     5500       16           22
# 1    3.50   2.80                8.8      101.0     5800       23           29
# 2    3.50   2.80                8.8      101.0     5800       23           29
# 3    3.31   3.19                9.0      121.0     4250       21           28
# 4    3.31   3.19                9.0      121.0     4250       21           28
# ..    ...    ...                ...        ...      ...      ...          ...
# 191  3.78   3.15                9.5      114.0     5400       23           28
# 192  3.78   3.15                8.7      160.0     5300       19           25
# 193  3.58   2.87                8.8      134.0     5500       18           23
# 194  3.01   3.40               23.0      106.0     4800       26           27
# 195  3.78   3.15                9.5      114.0     5400       19           25
#
#      price
# 0      NaN
# 1    16430
# 2    16925
# 3    20970
# 4    21105
# ..     ...
# 191  16845
# 192  19045
# 193  21485
# 194  22470
# 195  22625
#
# [196 rows x 24 columns]

# %%
autoprice_DF[autoprice_DF['make']=='audi']
# Out:
#    make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 3  audi       gas        std         four      sedan          fwd
# 4  audi       gas        std         four      sedan          4wd
# 5  audi       gas        std          two      sedan          fwd
# 6  audi       gas        std         four      sedan          fwd
# 7  audi       gas        std         four      wagon          fwd
# 8  audi       gas      turbo         four      sedan          fwd
# 9  audi       gas      turbo          two  hatchback          4wd
#
#   engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 3           front        99.8   176.6   66.2  ...          109         mpfi
# 4           front        99.4   176.6   66.4  ...          136         mpfi
# 5           front        99.8   177.3   66.3  ...          136         mpfi
# 6           front       105.8   192.7   71.4  ...          136         mpfi
# 7           front       105.8   192.7   71.4  ...          136         mpfi
# 8           front       105.8   192.7   71.4  ...          131         mpfi
# 9           front        99.5   178.2   67.9  ...          131         mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm city-mpg  highway-mpg  \
# 3  3.19   3.40               10.0      102.0     5500       24           30
# 4  3.19   3.40                8.0      115.0     5500       18           22
# 5  3.19   3.40                8.5      110.0     5500       19           25
# 6  3.19   3.40                8.5      110.0     5500       19           25
# 7  3.19   3.40                8.5      110.0     5500       19           25
# 8  3.13   3.40                8.3      140.0     5500       17           20
# 9  3.13   3.40                7.0      160.0     5500       16           22
#
#    price
# 3  13950
# 4  17450
# 5  15250
# 6  17710
# 7  18920
# 8  23875
# 9    NaN
#
# [7 rows x 24 columns]

# %%
autoprice_DF.filter()

# %%
autoprice_DF.filter(items ='make',like =='audi')#== 'audi'
# Out:
#   File "C:\Users\neroy\AppData\Local\Temp\ipykernel_16976\1044811948.py", line 1
#     autoprice_DF.filter(items ='make',like =='audi')#== 'audi'
#                                                    ^
# SyntaxError: positional argument follows keyword argument

# %%
autoprice_DF[(autoprice_DF['make']=='audi') & (autoprice_DF['horsepower']>110)]
# Out:
#    make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 4  audi       gas        std         four      sedan          4wd
# 8  audi       gas      turbo         four      sedan          fwd
# 9  audi       gas      turbo          two  hatchback          4wd
#
#   engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 4           front        99.4   176.6   66.4  ...          136         mpfi
# 8           front       105.8   192.7   71.4  ...          131         mpfi
# 9           front        99.5   178.2   67.9  ...          131         mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm city-mpg  highway-mpg  \
# 4  3.19   3.40                8.0      115.0     5500       18           22
# 8  3.13   3.40                8.3      140.0     5500       17           20
# 9  3.13   3.40                7.0      160.0     5500       16           22
#
#    price
# 4  17450
# 8  23875
# 9    NaN
#
# [3 rows x 24 columns]

# %%
# sample
autoprice_DF.sample(10)
# Out:
#            make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 24        dodge       gas        std         four  hatchback          fwd
# 107      peugot       gas        std         four      sedan          rwd
# 27        dodge       gas      turbo          NaN      sedan          fwd
# 91       nissan       gas        std          two      sedan          fwd
# 20    chevrolet       gas        std         four      sedan          fwd
# 79   mitsubishi       gas      turbo          two  hatchback          fwd
# 101      nissan       gas        std         four      sedan          fwd
# 154      toyota       gas        std         four      wagon          4wd
# 116      peugot    diesel      turbo         four      sedan          rwd
# 120    plymouth       gas        std         four  hatchback          fwd
#
#     engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 24            front        93.7   157.3   63.8  ...           90         2bbl
# 107           front       107.9   186.7   68.4  ...          120         mpfi
# 27            front        93.7   157.3   63.8  ...           98         mpfi
# 91            front        94.5   165.3   63.8  ...           97         2bbl
# 20            front        94.5   158.8   63.6  ...           90         2bbl
# 79            front        93.0   157.3   63.8  ...           98         spdi
# 101           front       100.4   181.7   66.5  ...          181         mpfi
# 154           front        95.7   169.7   63.6  ...           92         2bbl
# 116           front       107.9   186.7   68.4  ...          152          idi
# 120           front        93.7   157.3   63.8  ...           90         2bbl
#
#      bore stroke  compression-ratio horsepower peak-rpm city-mpg  highway-mpg  \
# 24   2.97   3.23                9.4       68.0     5500       31           38
# 107  3.46   3.19                8.4       97.0     5000       19           24
# 27   3.03   3.39                7.6      102.0     5500       24           30
# 91   3.15   3.29                9.4       69.0     5200       31           37
# 20   3.03   3.11                9.6       70.0     5400       38           43
# 79   3.03   3.39                7.6      102.0     5500       24           30
# 101  3.43   3.27                9.0      152.0     5200       17           22
# 154  3.05   3.03                9.0       62.0     4800       27           32
# 116  3.70   3.52               21.0       95.0     4150       28           33
# 120  2.97   3.23                9.4       68.0     5500       31           38
#
#      price
# 24    6229
# 107  11900
# 27    8558
# 91    6649
# 20    6575
# 79    7689
# 101  13499
# 154   7898
# 116  17950
# 120   6229
#
# [10 rows x 24 columns]

# %%
autoprice_DF.sample(frac = 0.1)
# Out:
#               make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 99          nissan       gas        std         four  hatchback          fwd
# 76      mitsubishi       gas        std          two  hatchback          fwd
# 166         toyota       gas        std          two  hatchback          rwd
# 176         toyota       gas        std         four      sedan          fwd
# 36           honda       gas        std         four      wagon          fwd
# 119       plymouth       gas      turbo          two  hatchback          fwd
# 58           mazda       gas        std          two  hatchback          rwd
# 12             bmw       gas        std          two      sedan          rwd
# 111         peugot       gas        std         four      sedan          rwd
# 66           mazda    diesel        std         four      sedan          rwd
# 40           honda       gas        std         four      sedan          fwd
# 97          nissan       gas        std         four      wagon          fwd
# 186     volkswagen       gas        std         four      sedan          fwd
# 68   mercedes-benz    diesel      turbo         four      wagon          rwd
# 63           mazda    diesel        std          NaN      sedan          fwd
# 49          jaguar       gas        std          two      sedan          rwd
# 59           mazda       gas        std          two  hatchback          fwd
# 26           dodge       gas        std         four      sedan          fwd
# 113         peugot       gas        std         four      wagon          rwd
# 159         toyota    diesel        std         four  hatchback          fwd
#
#     engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 99            front        97.2   173.4   65.2  ...          120         2bbl
# 76            front        93.7   157.3   64.4  ...           92         2bbl
# 166           front        94.5   168.7   64.0  ...           98         mpfi
# 176           front       102.4   175.6   66.5  ...          122         mpfi
# 36            front        96.5   157.1   63.9  ...           92         1bbl
# 119           front        93.7   157.3   63.8  ...           98         spdi
# 58            front        95.3   169.0   65.7  ...           80         mpfi
# 12            front       101.2   176.8   64.8  ...          164         mpfi
# 111           front       107.9   186.7   68.4  ...          120         mpfi
# 66            front       104.9   175.0   66.1  ...          134          idi
# 40            front        96.5   175.4   62.5  ...          110         1bbl
# 97            front        94.5   170.2   63.8  ...           97         2bbl
# 186           front        97.3   171.7   65.5  ...          109         mpfi
# 68            front       110.0   190.9   70.3  ...          183          idi
# 63            front        98.8   177.8   66.5  ...          122          idi
# 49            front       102.0   191.7   70.6  ...          326         mpfi
# 59            front        98.8   177.8   66.5  ...          122         2bbl
# 26            front        93.7   157.3   63.8  ...           90         2bbl
# 113           front       114.2   198.9   68.4  ...          120         mpfi
# 159           front        95.7   166.3   64.4  ...          110          idi
#
#      bore stroke  compression-ratio horsepower peak-rpm city-mpg  highway-mpg  \
# 99   3.33   3.47                8.5       97.0     5200       27           34
# 76   2.97   3.23                9.4       68.0     5500       37           41
# 166  3.24   3.08                9.4      112.0     6600       26           29
# 176  3.31   3.54                8.7       92.0     4200       27           32
# 36   2.92   3.41                9.2       76.0     6000       30           34
# 119  3.03   3.39                7.6      102.0     5500       24           30
# 58    NaN    NaN                9.4      135.0     6000       16           23
# 12   3.31   3.19                9.0      121.0     4250       21           28
# 111  3.46   2.19                8.4       95.0     5000       19           24
# 66   3.43   3.64               22.0       72.0     4200       31           39
# 40   3.15   3.58                9.0       86.0     5800       27           33
# 97   3.15   3.29                9.4       69.0     5200       31           37
# 186  3.19   3.40                9.0       85.0     5250       27           34
# 68   3.58   3.64               21.5      123.0     4350       22           25
# 63   3.39   3.39               22.7       64.0     4650       36           42
# 49   3.54   2.76               11.5      262.0     5000       13           17
# 59   3.39   3.39                8.6       84.0     4800       26           32
# 26   2.97   3.23                9.4       68.0     5500       31           38
# 113  3.46   2.19                8.4       95.0     5000       19           24
# 159  3.27   3.35               22.5       56.0     4500       38           47
#
#      price
# 99    8949
# 76    5389
# 166   9538
# 176  10898
# 36    7295
# 119   7957
# 58   15645
# 12   20970
# 111  15580
# 66   18344
# 40   10295
# 97    7999
# 186   8495
# 68   28248
# 63   10795
# 49   36000
# 59    8845
# 26    7609
# 113  16695
# 159   7788
#
# [20 rows x 24 columns]

# %%
autoprice_DF.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 205, dtype: bool

# %%
auto_df = autoprice_DF[['make']]

# %%
auto_df['dup_make'] = autoprice_DF[['make']]
# Out:
# C:\Users\neroy\AppData\Local\Temp\ipykernel_16976\2753720916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   auto_df['dup_make'] = autoprice_DF[['make']]

# %%
auto_df['length'] = autoprice_DF[['length']]
# Out:
# C:\Users\neroy\AppData\Local\Temp\ipykernel_16976\738970939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   auto_df['length'] = autoprice_DF[['length']]

# %%
auto_df
# Out:
#             make     dup_make  length
# 0    alfa-romero  alfa-romero   168.8
# 1    alfa-romero  alfa-romero   168.8
# 2    alfa-romero  alfa-romero   171.2
# 3           audi         audi   176.6
# 4           audi         audi   176.6
# ..           ...          ...     ...
# 200        volvo        volvo   188.8
# 201        volvo        volvo   188.8
# 202        volvo        volvo   188.8
# 203        volvo        volvo   188.8
# 204        volvo        volvo   188.8
#
# [205 rows x 3 columns]

# %%
type(auto_df)
# Out:
# pandas.core.frame.DataFrame

# %%
auto_df[auto_df.duplicated()].index
# Out:
# Int64Index([  1,   4,   7,   8,  11,  12,  13,  15,  22,  23,
#             ...
#             195, 196, 197, 198, 199, 200, 201, 202, 203, 204],
#            dtype='int64', length=121)

# %%
auto_df.duplicated()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 200     True
# 201     True
# 202     True
# 203     True
# 204     True
# Length: 205, dtype: bool

# %%
df = pd.DataFrame({
...     'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
...     'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
...     'rating': [4, 4, 3.5, 15, 5]
... })

# %%
print(df)
df.duplicated()
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0

# %%
df[df.duplicated()].index
# Out:
# Int64Index([1], dtype='int64')

# %% [markdown]
# ### Groupby()

# %%
autoprice_DF.groupby('make')[['city-mpg']].mean()
# Out:
#                 city-mpg
# make
# alfa-romero    20.333333
# audi           18.857143
# bmw            19.375000
# chevrolet      41.000000
# dodge          28.000000
# honda          30.384615
# isuzu          31.000000
# jaguar         14.333333
# mazda          25.705882
# mercedes-benz  18.500000
# mercury        19.000000
# mitsubishi     24.923077
# nissan         27.000000
# peugot         22.454545
# plymouth       28.142857
# porsche        17.400000
# renault        23.000000
# saab           20.333333
# subaru         26.333333
# toyota         27.500000
# volkswagen     28.583333
# volvo          21.181818

# %%
autoprice_DF.groupby('make').mean('city-mpg').sort_values(by = 'city-mpg',ascending = False)
# Out:
#                wheel-base      length      width     height  curb-weight  \
# make
# chevrolet       92.466667  151.933333  62.500000  52.400000  1757.000000
# isuzu           94.825000  163.775000  63.550000  52.225000  2213.500000
# honda           94.330769  160.769231  64.384615  53.238462  2096.769231
# volkswagen      97.608333  172.533333  65.616667  55.183333  2343.166667
# plymouth        95.385714  164.900000  64.271429  51.971429  2220.857143
# dodge           95.011111  160.988889  64.166667  51.644444  2151.333333
# toyota          98.103125  171.934375  65.090625  53.721875  2441.093750
# nissan          95.722222  170.988889  65.088889  53.633333  2400.388889
# subaru          96.175000  168.858333  64.950000  53.750000  2316.250000
# mazda           97.017647  170.805882  65.588235  53.358824  2297.823529
# mitsubishi      95.353846  168.030769  65.253846  50.692308  2381.923077
# renault         96.100000  179.150000  66.550000  52.850000  2519.500000
# peugot         110.200000  191.136364  68.390909  57.181818  3221.000000
# volvo          106.481818  188.800000  67.963636  56.236364  3037.909091
# saab            99.100000  186.600000  66.500000  56.100000  2745.500000
# alfa-romero     90.566667  169.600000  64.566667  50.000000  2639.666667
# bmw            103.162500  184.500000  66.475000  54.825000  2929.375000
# mercury        102.700000  178.400000  68.000000  54.800000  2910.000000
# audi           102.271429  183.828571  68.714286  54.428571  2800.714286
# mercedes-benz  110.925000  195.262500  71.062500  55.725000  3696.250000
# porsche         92.280000  170.260000  67.120000  51.100000  2891.200000
# jaguar         109.333333  196.966667  69.933333  51.133333  4027.333333
#
#                engine-size  compression-ratio  horsepower   city-mpg  \
# make
# chevrolet        80.333333           9.566667    62.65625  41.000000
# isuzu           102.500000           9.225000    77.00000  31.000000
# honda            99.307692           9.215385    80.25000  30.384615
# volkswagen      107.250000          13.625000    81.06250  28.583333
# plymouth        106.285714           8.671429    86.68750  28.142857
# dodge           102.666667           8.634444    86.31250  28.000000
# toyota          118.812500          10.340625    92.75000  27.500000
# nissan          127.888889           9.794444   102.56250  27.000000
# subaru          107.083333           8.816667    86.25000  26.333333
# mazda           103.000000          10.488235    85.50000  25.705882
# mitsubishi      118.307692           8.061538   104.06250  24.923077
# renault         132.000000           8.700000         NaN  23.000000
# peugot          135.818182          14.000000    99.81250  22.454545
# volvo           142.272727          10.227273   128.00000  21.181818
# saab            121.000000           9.201667   126.68750  20.333333
# alfa-romero     137.333333           9.000000   125.31250  20.333333
# bmw             166.875000           8.575000   138.87500  19.375000
# mercury         140.000000           8.000000   175.00000  19.000000
# audi            130.714286           8.400000   121.00000  18.857143
# mercedes-benz   226.500000          14.825000   146.25000  18.500000
# porsche         187.200000           9.600000   210.37500  17.400000
# jaguar          280.666667           9.233333   204.62500  14.333333
#
#                highway-mpg
# make
# chevrolet        46.333333
# isuzu            36.000000
# honda            35.461538
# volkswagen       34.916667
# plymouth         34.142857
# dodge            34.111111
# toyota           32.906250
# nissan           32.944444
# subaru           30.750000
# mazda            31.941176
# mitsubishi       31.153846
# renault          31.000000
# peugot           26.636364
# volvo            25.818182
# saab             27.333333
# alfa-romero      26.666667
# bmw              25.375000
# mercury          24.000000
# audi             24.142857
# mercedes-benz    21.000000
# porsche          26.000000
# jaguar           18.333333

# %%
autoprice_DF.groupby('make')[['city-mpg']].mean().sort_values(by = 'city-mpg',ascending = False)
# Out:
#                 city-mpg
# make
# chevrolet      41.000000
# isuzu          31.000000
# honda          30.384615
# volkswagen     28.583333
# plymouth       28.142857
# dodge          28.000000
# toyota         27.500000
# nissan         27.000000
# subaru         26.333333
# mazda          25.705882
# mitsubishi     24.923077
# renault        23.000000
# peugot         22.454545
# volvo          21.181818
# saab           20.333333
# alfa-romero    20.333333
# bmw            19.375000
# mercury        19.000000
# audi           18.857143
# mercedes-benz  18.500000
# porsche        17.400000
# jaguar         14.333333
